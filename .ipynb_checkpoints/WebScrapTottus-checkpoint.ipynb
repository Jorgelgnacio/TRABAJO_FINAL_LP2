# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from pymongo import MongoClient

# %%
path = ('C:/Users/jorge/Documents/TRABAJO FINAL/chromedriver.exe')
urls='https://www.tottus.com.pe/abarrotes-4010000/c/?sort=Recomendados'
options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s = Service(path)
driver = webdriver.Chrome(service=s, options = options)
driver.get(urls)
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 8>()
#       6 driver = webdriver.Chrome(service=s, options = options)
#       7 driver.get(urls)
# ----> 8 time.sleep(5)
#
# KeyboardInterrupt:

# %%
WebDriverWait(driver, 10)\
    .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
                                      'button.align-right secondary slidedown-button'.replace(' ', '.'))))\
    .click()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 WebDriverWait(driver, 10)\
#       2     .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
#       3                                       'button.align-right secondary slidedown-button'.replace(' ', '.'))))\
#       4     .click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py:87, in WebDriverWait.until(self, method, message)
#      85     screen = getattr(exc, 'screen', None)
#      86     stacktrace = getattr(exc, 'stacktrace', None)
# ---> 87 time.sleep(self._poll)
#      88 if time.monotonic() > end_time:
#      89     break
#
# KeyboardInterrupt:

# %%
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
                                      'input#catalystSearchBar')))\
    .click()

# %%
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
                                      'input#inputSearchBar')))\
    .send_keys('aceite')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 WebDriverWait(driver, 5)\
#       2     .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
#       3                                       'input#inputSearchBar')))\
#       4     .send_keys('aceite')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py:90, in WebDriverWait.until(self, method, message)
#      88     if time.monotonic() > end_time:
#      89         break
# ---> 90 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00A06463+2188387]
# 	Ordinal0 [0x0099E461+1762401]
# 	Ordinal0 [0x008B3D78+802168]
# 	Ordinal0 [0x008E1880+989312]
# 	Ordinal0 [0x008E1B1B+989979]
# 	Ordinal0 [0x0090E912+1173778]
# 	Ordinal0 [0x008FC824+1099812]
# 	Ordinal0 [0x0090CC22+1166370]
# 	Ordinal0 [0x008FC5F6+1099254]
# 	Ordinal0 [0x008D6BE0+945120]
# 	Ordinal0 [0x008D7AD6+948950]
# 	GetHandleVerifier [0x00CA71F2+2712546]
# 	GetHandleVerifier [0x00C9886D+2652765]
# 	GetHandleVerifier [0x00A9002A+520730]
# 	GetHandleVerifier [0x00A8EE06+516086]
# 	Ordinal0 [0x009A468B+1787531]
# 	Ordinal0 [0x009A8E88+1805960]
# 	Ordinal0 [0x009A8F75+1806197]
# 	Ordinal0 [0x009B1DF1+1842673]
# 	BaseThreadInitThunk [0x761A6739+25]
# 	RtlGetFullPathName_UEx [0x77348FEF+1215]
# 	RtlGetFullPathName_UEx [0x77348FBD+1165]

# %%
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.CSS_SELECTOR,
                                      'button.jsx-2851002401.searchIcon')))\
    .click()

# %%
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.XPATH,
                                      '/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[6]')))\
    .click()

# %%
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.XPATH,
                                      '/html/body/div[1]/section/div[1]/section/div[2]/div[2]/ul[1]')))


pag = driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[5]')
pag=pag.text
def n_pag(pag):
    if pag=="Siguiente":
        pag = driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[4]')
        pag=pag.text
        print(pag)
    else:
        if int(pag)>3:
            pag = driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[5]')
            pag=pag.text
            print(pag)
        else:
            if pag==3:
                pag = driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[4]')
                pag=pag.text
                print(pag.text)
            else:
                if pag==2:
                    pag= driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[3]')
                    pag=pag.text
                    print(pag.text)
                else:
                    pag= driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[2]')
                    pag=pag.text
                    print(pag.text)
n_pag(pag)
pag
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [17], in <cell line: 6>()
#       1 WebDriverWait(driver, 5)\
#       2     .until(EC.element_to_be_clickable((By.XPATH,
#       3                                       '/html/body/div[1]/section/div[1]/section/div[2]/div[2]/ul[1]')))
# ----> 6 pag = driver.find_element("xpath",'/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[5]')
#       7 pag=pag.text
#       8 def n_pag(pag):
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:857, in WebDriver.find_element(self, by, value)
#     854     by = By.CSS_SELECTOR
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/section/div[1]/section/div[1]/div[2]/ul/li[5]"}
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00A06463+2188387]
# 	Ordinal0 [0x0099E461+1762401]
# 	Ordinal0 [0x008B3D78+802168]
# 	Ordinal0 [0x008E1880+989312]
# 	Ordinal0 [0x008E1B1B+989979]
# 	Ordinal0 [0x0090E912+1173778]
# 	Ordinal0 [0x008FC824+1099812]
# 	Ordinal0 [0x0090CC22+1166370]
# 	Ordinal0 [0x008FC5F6+1099254]
# 	Ordinal0 [0x008D6BE0+945120]
# 	Ordinal0 [0x008D7AD6+948950]
# 	GetHandleVerifier [0x00CA71F2+2712546]
# 	GetHandleVerifier [0x00C9886D+2652765]
# 	GetHandleVerifier [0x00A9002A+520730]
# 	GetHandleVerifier [0x00A8EE06+516086]
# 	Ordinal0 [0x009A468B+1787531]
# 	Ordinal0 [0x009A8E88+1805960]
# 	Ordinal0 [0x009A8F75+1806197]
# 	Ordinal0 [0x009B1DF1+1842673]
# 	BaseThreadInitThunk [0x761A6739+25]
# 	RtlGetFullPathName_UEx [0x77348FEF+1215]
# 	RtlGetFullPathName_UEx [0x77348FBD+1165]

# %%
elements = driver.find_elements(By.XPATH,'//li[@class="product"]')
names =  []
prices = []
for element in elements:
        name = element.find_element(By.XPATH,'.//h2[@class="jsx-369422875 name title mini"]').text
        price = element.find_element(By.XPATH,'.//span[@class="jsx-4019956066 "]').text
        names.append(name)
        prices.append(price)
len(elements)
# Out:
# 48

# %%
a=driver.find_element(By.XPATH,'//*[@id="container"]/div[1]/section/div[1]/div[3]/ul/li[5]/a').text
type(int(a))
# Out:
# int

# %%
dic= {'Producto': names,"Precio": prices }
df = pd.DataFrame(dic , columns= ["Producto","Precio"] )
df.to_excel('tottus.xlsx', index=False,encoding='cp1252')

# Lectura
pd.read_excel('tottus.xlsx')
# Out:
#                                              Producto                Precio
# 0   ACEITUNA BOTIJA LUGHT ENTERA OLIVOS DEL SUR 30...             s/ 9.1 UN
# 1                 TAPENADE ACEITUNAS ALCACHOFA 185 GR               s/ 6 UN
# 2                    TAPENADE MIX DE ACEITUNAS 185 GR               s/ 6 UN
# 3                 TAPENADE DE ACEITUNAS AL AJÍ 185 GR               s/ 6 UN
# 4              ACEITUNAS RELLENAS ANCHOA TOTTUS 200 G             s/ 4.9 UN
# 5           ACEITUNAS RELLENAS DE QUESO TOTTUS 200 GR             s/ 4.9 UN
# 6         ACEITUNAS RELLENAS DE PIMIENTO TOTTUS 200 G             s/ 4.9 UN
# 7          ACEITUNAS RELLENAS DE SALMON TOTTUS 200 GR             s/ 4.9 UN
# 8            ACEITUNAS RELLENAS DE ATUN TOTTUS 200 GR             s/ 4.9 UN
# 9              ACEITUNAS RELLENAS DE AJO TOTTUS 200 G             s/ 4.9 UN
# 10             ACEITUNAS RELLENAS ANCHOA TOTTUS 350 G             s/ 7.3 UN
# 11           ACEITUNAS RELLENAS PIMIENTO TOTTUS 350 G             s/ 7.3 UN
# 12            ACEITUNAS RELLENAS SALMON TOTTUS 350 GR             s/ 7.3 UN
# 13          ACEITUNAS RELLENAS DE QUESO TOTTUS 350 GR             s/ 7.3 UN
# 14           ACEITUNAS VERDES DESHUESADAS TOTTUS 235G             s/ 5.9 UN
# 15               ACEITUNA VERDE RODAJAS TOTTUS 230 GR             s/ 5.9 UN
# 16          ACEITUNAS RELLENAS DE LIMÓN TOTTUS 200 GR             s/ 4.9 UN
# 17             ALCAPARRAS GOURMET VALLE FÉRTIL 210 GR            s/ 20.5 UN
# 18                      HUMMUS DIP TRADICIONAL 240 GR              s/ 19 UN
# 19                   PIMIENTO PIQUILLO GOURMET 290 GR            s/ 11.9 UN
# 20                           JALAPEÑOS GOURMET 225 GR             s/ 8.5 UN
# 21                  DURAZNOS TOTTUS EN MITADES 820 GR            s/ 10.5 UN
# 22                                DURAZNOS EN ALMIBAR            s/ 13.8 UN
# 23          RODAJAS DE PIÑA EN CONSERVA TOTTUS 565 GR  s/ 6.9 UN\ns/ 7.1 UN
# 24                       PIÑA EN TROZOS TOTTUS 565 GR  s/ 5.9 UN\ns/ 6.5 UN
# 25  CREMA DE ZAPALLO Y NUEZ MOSCADA TOTTUS LIFE 35...             s/ 6.9 UN
# 26    CONSERVA DE FRIJOLES BLANCOS EN SALMUERA 400 GR             s/ 3.9 UN
# 27      CREMA DE TOMATE Y ALBAHACA TOTTUS LIFE 350 GR             s/ 6.9 UN
# 28      ACEITE OLIVA EXTRA VIRGEN SPRAY TOTTUS 200 ML            s/ 21.5 UN
# 29                 ACEITE GIRASOL SPRAY TOTTUS 200 ML            s/ 21.5 UN
# 30                        ACEITE CANOLA TOTTUS 200 ML            s/ 21.5 UN
# 31     CREMA DE ZANAHORIA Y CAMOTE TOTTUS LIFE 350 GR             s/ 6.9 UN
# 32     CONSERVA DE FRIJOLES NEGROS EN SALMUERA 400 GR             s/ 3.9 UN
# 33            CREMA DE 7 VEGETALES TOTTUS LIFE 350 GR             s/ 6.9 UN
# 34           CONSERVA DE GARBANZOS EN SALMUERA 400 GR             s/ 3.9 UN
# 35      CONSERVA DE FRIJOLES ROJOS EN SALMUERA 400 GR             s/ 3.9 UN
# 36       ACEITUNA BOTIJA ENTERA OLIVOS DEL SUR 850 GR            s/ 12.5 UN
# 37                     ACEITUNA VERDE PIMIENTO 380 GR             s/ 9.8 UN
# 38                 RELISH GOURMET VALLE FÉRTIL 340 GR            s/ 10.3 UN
# 39                VEGETALES MIXTOS EN CONSERVA 425 GR             s/ 7.7 UN
# 40                         ACEITUNAS DE BOTIJA 240 GR             s/ 7.9 UN
# 41                  ACEITUNA VERDE CON CASTAÑA 240 GR             s/ 8.5 UN
# 42                              ACEITUNA BOTIJA EXTRA             s/ 8.5 UN
# 43              PEPINILLOS CRUJIENTES ALIÑADOS 720 ML            s/ 25.2 UN
# 44                 PEPINILLOS SALZ-DILL-GURKEN 720 ML            s/ 31.5 UN
# 45           TAPENADE ALCACHOFAS A LA ITALIANA 185 GR             s/ 7.9 UN
# 46               TAPENADE ACEITUNAS AGRIDULCES 109 GR             s/ 7.9 UN
# 47                      TAPENADE CON ALCACHOFA 260 GR            s/ 13.1 UN

# %%
n=1
while n<int(pag):
    av=[]
    elements = driver.find_elements(By.XPATH,'//li[@class="product"]')
    av.append(elements)
    print(av)
    n=n+1
# Out:
# [[<selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="095fcf90-fd00-45aa-955f-245e1f69b29a")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="c24b5025-b511-4bbc-9cc6-48b41c84c766")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="82ce774c-8320-47bb-8bac-2fd40e69f44f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="3511ac7d-c497-4a0b-b6f1-092979b56a5e")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="bf0bef51-7e4e-4dbd-b777-c2ef50a4c311")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="e0aa780d-1208-4b15-9d99-318e3cd99f54")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="9ebc7a37-93c3-40bf-9380-1dd79e58afb5")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="7d8b42e5-49df-4a85-ba20-8564e0eb2b49")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="38aac122-44bb-4e5c-ace3-8d352010f438")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="71ead1f6-792b-4841-bf90-2cb671268a34")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6cbd4555-d542-4f2e-9af4-626b8940d549")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="f9f267f2-60ec-49b1-9a59-3603177baabc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f10b6c9-8f03-4339-8fb9-fd5153452e17")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="a19ddc76-af5b-4455-9b6e-3fcc4449bec1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="dc434a8f-8887-4782-9ee9-61baa5dbb2a7")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="596034fe-c935-4a8a-845c-1b604484092d")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="0f54bfb0-766d-446f-8de2-82bdfbab7b93")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="5b91b81a-4936-497c-8d2f-71f9fd844750")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="28ce74e9-6434-49c3-a270-2e1cbda0eca0")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="83ddeea6-1862-4fb8-a435-692788bb709f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="d1873858-4c95-4d07-b27c-1263c5152692")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6a3d1331-167b-470f-9ef1-070c40687769")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f5d1009-6d97-4e7c-8eff-ae0af4fbdd62")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="145257de-4a56-4f0c-b62a-97f00878c9e1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="667ca8b1-f743-46e7-b119-5509273fa980")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="b25b5991-c456-4c66-8781-9e83748e97dd")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1201eeba-9248-40e2-a2b9-2a1be157b8dc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6b2673a ...
# [[<selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="095fcf90-fd00-45aa-955f-245e1f69b29a")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="c24b5025-b511-4bbc-9cc6-48b41c84c766")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="82ce774c-8320-47bb-8bac-2fd40e69f44f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="3511ac7d-c497-4a0b-b6f1-092979b56a5e")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="bf0bef51-7e4e-4dbd-b777-c2ef50a4c311")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="e0aa780d-1208-4b15-9d99-318e3cd99f54")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="9ebc7a37-93c3-40bf-9380-1dd79e58afb5")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="7d8b42e5-49df-4a85-ba20-8564e0eb2b49")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="38aac122-44bb-4e5c-ace3-8d352010f438")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="71ead1f6-792b-4841-bf90-2cb671268a34")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6cbd4555-d542-4f2e-9af4-626b8940d549")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="f9f267f2-60ec-49b1-9a59-3603177baabc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f10b6c9-8f03-4339-8fb9-fd5153452e17")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="a19ddc76-af5b-4455-9b6e-3fcc4449bec1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="dc434a8f-8887-4782-9ee9-61baa5dbb2a7")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="596034fe-c935-4a8a-845c-1b604484092d")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="0f54bfb0-766d-446f-8de2-82bdfbab7b93")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="5b91b81a-4936-497c-8d2f-71f9fd844750")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="28ce74e9-6434-49c3-a270-2e1cbda0eca0")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="83ddeea6-1862-4fb8-a435-692788bb709f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="d1873858-4c95-4d07-b27c-1263c5152692")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6a3d1331-167b-470f-9ef1-070c40687769")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f5d1009-6d97-4e7c-8eff-ae0af4fbdd62")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="145257de-4a56-4f0c-b62a-97f00878c9e1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="667ca8b1-f743-46e7-b119-5509273fa980")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="b25b5991-c456-4c66-8781-9e83748e97dd")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1201eeba-9248-40e2-a2b9-2a1be157b8dc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6b2673a ...
# [[<selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="095fcf90-fd00-45aa-955f-245e1f69b29a")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="c24b5025-b511-4bbc-9cc6-48b41c84c766")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="82ce774c-8320-47bb-8bac-2fd40e69f44f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="3511ac7d-c497-4a0b-b6f1-092979b56a5e")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="bf0bef51-7e4e-4dbd-b777-c2ef50a4c311")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="e0aa780d-1208-4b15-9d99-318e3cd99f54")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="9ebc7a37-93c3-40bf-9380-1dd79e58afb5")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="7d8b42e5-49df-4a85-ba20-8564e0eb2b49")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="38aac122-44bb-4e5c-ace3-8d352010f438")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="71ead1f6-792b-4841-bf90-2cb671268a34")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6cbd4555-d542-4f2e-9af4-626b8940d549")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="f9f267f2-60ec-49b1-9a59-3603177baabc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f10b6c9-8f03-4339-8fb9-fd5153452e17")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="a19ddc76-af5b-4455-9b6e-3fcc4449bec1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="dc434a8f-8887-4782-9ee9-61baa5dbb2a7")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="596034fe-c935-4a8a-845c-1b604484092d")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="0f54bfb0-766d-446f-8de2-82bdfbab7b93")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="5b91b81a-4936-497c-8d2f-71f9fd844750")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="28ce74e9-6434-49c3-a270-2e1cbda0eca0")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="83ddeea6-1862-4fb8-a435-692788bb709f")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="d1873858-4c95-4d07-b27c-1263c5152692")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6a3d1331-167b-470f-9ef1-070c40687769")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1f5d1009-6d97-4e7c-8eff-ae0af4fbdd62")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="145257de-4a56-4f0c-b62a-97f00878c9e1")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="667ca8b1-f743-46e7-b119-5509273fa980")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="b25b5991-c456-4c66-8781-9e83748e97dd")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="1201eeba-9248-40e2-a2b9-2a1be157b8dc")>, <selenium.webdriver.remote.webelement.WebElement (session="fff114c2885f0c0185aba4f2b82e6994", element="6b2673a ...

# %%
for element in elements:
    name = element.find_element(By.XPATH,'.//h2[@class="jsx-369422875 name title mini"]').text
    price = element.find_element(By.XPATH,'.//span[@class="jsx-4019956066 "]').text
    names.append(name)
    prices.append(price)
dic= {'Producto': names,"Precio": prices }
df = pd.DataFrame(dic , columns= ["Producto","Precio"] )
df.to_excel('tottus.xlsx', index=False,encoding='cp1252')

# Lectura
pd.read_excel('tottus.xlsx')
# Out:
#                                     Producto                           Precio
# 0                 ARROZ INTEGRAL TOTTUS 5 KG                       s/ 20.9 UN
# 1    ARROZ EXTRA AÑEJO TOTTUS PREMIUM 750 GR                        s/ 3.9 UN
# 2         ARROZ EXTRA INTEGRAL TOTTUS 750 GR                        s/ 3.7 UN
# 3                ARROZ SUPERIOR TOTTUS 10 KG  s/ 31.9 UN\nP. Reg.: s/ 34.6 UN
# 4                  ARROZ EXTRA TOTTUS 750 GR                        s/ 3.5 UN
# ..                                       ...                              ...
# 91                 BEBIDA DE ARROZ ORASI 1LT                       s/ 17.6 UN
# 92   SAZONADOR DE ARROZ DELIARROZ 6 UNIDADES                        s/ 1.9 UN
# 93             KIT DE PAELLA EL AVIÓN PARA 6                       s/ 99.9 UN
# 94  FETUCCINI ARROZ Y YUCA SIN GLUTEN 400 GR                       s/ 18.3 UN
# 95    GALLETAS DE ARROZ DULCE COSTEÑO 150 GR                        s/ 6.9 UN
#
# [96 rows x 2 columns]
